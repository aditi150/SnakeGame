# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi150/SnakeGame/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import learning_curve
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('/content/uci_dataset.csv')
dataset.head()
# Out:
#    144552912  9.3498486  56.7408757  17.05277157
# 0  144552912   9.350188   56.740679    17.614840
# 1  144552912   9.350549   56.740544    18.083536
# 2  144552912   9.350806   56.740485    18.279465
# 3  144552912   9.351053   56.740486    18.422974
# 4  144552912   9.351475   56.740502    19.124889

# %%
dataset.shape
# Out:
# (434873, 4)

# %%
dataset.isnull().sum()
# Out:
# 144552912      0
# 9.3498486      0
# 56.7408757     0
# 17.05277157    0
# dtype: int64

# %%
dataset = dataset.drop(['144552912'],axis=1)

# %%
sns.countplot(x = '9.3498486', data=dataset)

# %%
X = dataset.iloc[:,0:-1]
y = dataset['9.3498486']

# %%
ss = StandardScaler()
ss.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-0949f7bfeaad> in <cell line: 2>()
#       1 ss = StandardScaler()
# ----> 2 ss.fit_transform(X)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
# ...

# %%
samples = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=i)
    samples.append((X_train, X_test, y_train, y_test))

# %%
samples
# Out:
# [(        144552912  9.3498486  56.7408757
#   258685  144313644   8.362287   56.743928
#   160781  103163358   9.272580   56.855249
#   225045  152605357  10.417185   57.457602
#   3393     23075889  10.502329   57.445262
#   109516   38026941   9.868709   57.508292
#   ...           ...        ...         ...
#   122579   38050156   9.625442   57.282705
#   304137   96187459  10.051241   57.007115
#   152315  144038360  10.122457   56.906827
#   117952   95712399   9.921597   57.320714
#   305711   95140983   9.815592   57.282707
#
#   [219101 rows x 3 columns],
#           144552912  9.3498486  56.7408757
#   169989  115768906  10.337101   57.031937
#   135439  117147132  10.195921   57.398428
#   195882  146239742  10.251950   57.351864
#   226588  106469850   9.971426   57.018857
#   223323   93879858  10.032706   57.104141
#   ...           ...        ...         ...
#   11046    44069376   9.993745   57.025409
#   138265  107297561  10.472440   57.473886
# ...

# %%
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
result = pd.DataFrame(columns=['Sample', 'Best Accuracy', 'Best Kernel', 'Best Nu', 'Best Epsilon'])

# %%
def fitnessFunction(kernel, C, gamma):
  svm = SVC(kernel=kernel, C=C, gamma=gamma, max_iter=1000)
  svm.fit(X_train, y_train)
  y_pred = svm.predict(X_test)
  return accuracy_score(y_pred, y_test)

# %%
X = X.dropna()

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# %%
for i in range(len(samples)):
  best_accuracy = 0
  best_C = 0
  best_gamma = 0
  for kernel in kernels:
    X_train, X_test, y_train, y_test = samples[i]
    C = np.random.uniform(0, 10)
    gamma = np.random.uniform(0, 10)
    score = fitnessFunction(kernel, C, gamma)
    if score>best_accuracy:
      best_accuracy = round(score, 2)
      best_C = round(C, 2)
      best_gamma = round(gamma, 2)
      best_kernel = kernel
  print('Best Accuracy = ', best_accuracy, 'Best Kernel = ', best_kernel, 'Best Nu = ', best_C, 'Best Epsilon = ', best_gamma)
  result.loc[i] = [i+1, best_accuracy, best_kernel, best_C, best_gamma]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-97c7c4e77513> in <cell line: 1>()
#       7     C = np.random.uniform(0, 10)
#       8     gamma = np.random.uniform(0, 10)
# ----> 9     score = fitnessFunction(kernel, C, gamma)
#      10     if score>best_accuracy:
#      11       best_accuracy = round(score, 2)
#
# <ipython-input-15-7a29ca100345> in fitnessFunction(kernel, C, gamma)
#       1 def fitnessFunction(kernel, C, gamma):
#       2   svm = SVC(kernel=kernel, C=C, gamma=gamma, max_iter=1000)
# ----> 3   svm.fit(X_train, y_train)
#       4   y_pred = svm.predict(X_test)
#       5   return accuracy_score(y_pred, y_test)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     190             check_consistent_length(X, y)
#     191         else:
# --> 192             X, y = self._validate_data(
# ...

# %%
result
# Out:
# Empty DataFrame
# Columns: [Sample, Best Accuracy, Best Kernel, Best Nu, Best Epsilon]
# Index: []

# %%
X_train, X_test, y_train, y_test = samples[result['Best Accuracy'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-87172a0a70cd> in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = samples[result['Best Accuracy'].idxmax()]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2562         nan
#    2563         """
# -> 2564         i = self.argmax(axis, skipna, *args, **kwargs)
#    2565         if i == -1:
#    2566             return np.nan
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/base.py in argmax(self, axis, skipna, *args, **kwargs)
#     653             # error: Incompatible return value type (got "Union[int, ndarray]", expected
#     654             # "int")
# --> 655             return nanops.nanargmax(  # type: ignore[return-value]
#     656                 delegate, skipna=skipna
#     657             )
#
# ...

# %%
train_sizes, train_scores, test_scores = learning_curve(SVC(kernel=result['Best Kernel'].iloc[result['Best Accuracy'].idxmax()], 
                                                        C=result['Best Nu'].iloc[result['Best Accuracy'].idxmax()],
                                                        gamma=result['Best Epsilon'].iloc[result['Best Accuracy'].idxmax()],
                                                        max_iter = 1000), X_train, y_train, cv=10, scoring='accuracy', n_jobs=-1,
                                                        train_sizes = np.linspace(0.01, 1.0, 50))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-4d9897c3435c> in <cell line: 1>()
# ----> 1 train_sizes, train_scores, test_scores = learning_curve(SVC(kernel=result['Best Kernel'].iloc[result['Best Accuracy'].idxmax()],
#       2                                                         C=result['Best Nu'].iloc[result['Best Accuracy'].idxmax()],
#       3                                                         gamma=result['Best Epsilon'].iloc[result['Best Accuracy'].idxmax()],
#       4                                                         max_iter = 1000), X_train, y_train, cv=10, scoring='accuracy', n_jobs=-1,
#       5                                                         train_sizes = np.linspace(0.01, 1.0, 50))
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2562         nan
# ...
